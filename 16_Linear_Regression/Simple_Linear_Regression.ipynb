# %% [markdown]
# <a href="https://colab.research.google.com/github/vikrampal12345/Machine_learning/blob/main/16_Linear_Regression/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Simple Linear Regression - only one input column
# ## Multiple Linear Regression - more than two imput column
# ## Polynomial Linear Regression - when data is not linear

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/placement_linear.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
sns.scatterplot(data=df, x='cgpa', y='package')
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
from sklearn.model_selection import train_test_split
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score

lr = LinearRegression()

lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3626/4169768073.py in <cell line: 0>()
#       7 y_pred = lr.predict(X_test)
#       8
# ----> 9 accuracy_score(y_test, y_pred)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     225     # Compute accuracy for each possible representation
#     226     y_true, y_pred = attach_unique(y_true, y_pred)
# ...

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.09324469])

# %%
sns.regplot(data=df, x='cgpa', y='package')
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
m = lr.coef_   # slope
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_  # b
b
# Out:
# np.float64(-0.8961119222429144)

# %%
# y = mx + b

# %%
y = m*8.58 + b
y
# Out:
# array([3.89111601])

# %%
m * 10 + b
# Out:
# array([4.68340781])

# %%
# m -> consist the weightage
